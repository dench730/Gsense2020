# %%
import os
import ccdproc
import glob
import subprocess
import itertools
import numpy as np
from astropy import units as u
from astropy.io import fits
from astropy.coordinates import SkyCoord
from astropy.wcs import utils as wcsutils
from astropy.table import Table
from astropy.stats import sigma_clip
from astroquery.simbad import Simbad
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import rc, rcParams
import ccdproc as cp
from ccdproc import *

# %%
lightlist1=['94nm-0005-0d01s.fit','dark-0d01s-average.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0005-0d01s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./dark-0d01s-average.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0005-0d01s-subdark.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0005-0d01s-subdark.fit')

lightlist1=['94nm-0006-0d01s.fit','dark-0d01s-average.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0006-0d01s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./dark-0d01s-average.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0006-0d01s-subdark.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0006-0d01s-subdark.fit')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.246759 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.318634 from DATE-OBS'. [astropy.wcs.wcs]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.246782 from DATE-OBS'. [astropy.wcs.wcs]

# %%
lightlist1=['94nm-0005-0d04s.fit','dark-0d04s-average.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0005-0d04s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./dark-0d04s-average.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0005-0d04s-subdark.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0005-0d04s-subdark.fit')

lightlist1=['94nm-0006-0d04s.fit','dark-0d04s-average.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0006-0d04s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./dark-0d04s-average.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0006-0d04s-subdark.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0006-0d04s-subdark.fit')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.247199 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.319190 from DATE-OBS'. [astropy.wcs.wcs]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.247222 from DATE-OBS'. [astropy.wcs.wcs]

# %%
lightlist1=['94nm-0005-0d06s.fit','dark-0d06s-average.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0005-0d06s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./dark-0d06s-average.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0005-0d06s-subdark.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0005-0d06s-subdark.fit')

lightlist1=['94nm-0006-0d06s.fit','dark-0d06s-average.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0006-0d06s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./dark-0d06s-average.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0006-0d06s-subdark.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0006-0d06s-subdark.fit')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.247419 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.321400 from DATE-OBS'. [astropy.wcs.wcs]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.247442 from DATE-OBS'. [astropy.wcs.wcs]

# %%
lightlist1=['94nm-0005-0d02s.fit','dark-0d02s-average.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0005-0d02s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./dark-0d02s-average.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0005-0d02s-subdark.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0005-0d02s-subdark.fit')

lightlist1=['94nm-0006-0d02s.fit','dark-0d02s-average.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0006-0d02s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./dark-0d02s-average.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0006-0d02s-subdark.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0006-0d02s-subdark.fit')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.246979 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.318819 from DATE-OBS'. [astropy.wcs.wcs]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.247002 from DATE-OBS'. [astropy.wcs.wcs]

# %%
lightlist1=['94nm-0005-0d01s-subdark.fit','94nm-0006-0d01s-subdark.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0005-0d01s-subdark.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./94nm-0006-0d01s-subdark.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0d01s-subdark-5sub6.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0d01s-subdark-5sub6.fit')
    
ret = os.access("94nm-0d01s-subdark-ave.fit", os.F_OK)
if(ret==False):
    avgccd = combine(lightlist1, output_file='94nm-0d01s-subdark-ave.fit',  
                     method='average', unit=u.adu)
# Out:
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]

# %%
lightlist1=['94nm-0005-0d06s-subdark.fit','94nm-0006-0d06s-subdark.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0005-0d06s-subdark.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./94nm-0006-0d06s-subdark.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0d06s-subdark-5sub6.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0d06s-subdark-5sub6.fit')
    
ret = os.access("94nm-0d06s-subdark-ave.fit", os.F_OK)
if(ret==False):
    avgccd = combine(lightlist1, output_file='94nm-0d06s-subdark-ave.fit',  
                     method='average', unit=u.adu)
# Out:
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]

# %%
lightlist1=['94nm-0005-0d04s-subdark.fit','94nm-0006-0d04s-subdark.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0005-0d04s-subdark.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./94nm-0006-0d04s-subdark.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0d04s-subdark-5sub6.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0d04s-subdark-5sub6.fit')
    
ret = os.access("94nm-0d04s-subdark-ave.fit", os.F_OK)
if(ret==False):
    avgccd = combine(lightlist1, output_file='94nm-0d04s-subdark-ave.fit',  
                     method='average', unit=u.adu)
# Out:
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]

# %%
lightlist1=['94nm-0005-0d02s-subdark.fit','94nm-0006-0d02s-subdark.fit']
image1_1 = ccdproc.CCDData.read('./94nm-0005-0d02s-subdark.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./94nm-0006-0d02s-subdark.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("94nm-0d02s-subdark-5sub6.fit", os.F_OK)
if(ret==False):
    sub_img.write('./94nm-0d02s-subdark-5sub6.fit')
    
ret = os.access("94nm-0d02s-subdark-ave.fit", os.F_OK)
if(ret==False):
    avgccd = combine(lightlist1, output_file='94nm-0d02s-subdark-ave.fit',  
                     method='average', unit=u.adu)
# Out:
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]

# %%
# def takemean( path ):
#     fh=fits.open(path)     
#     return  fh[0].data[1020:1060,850:950].mean()

# def takevariance( path ):
#     fh=fits.open(path)
#     return  fh[0].data[1020:1060,850:950].var()/2

# def takestd( path ):
#     fh=fits.open(path)
#     return  fh[0].data[1020:1060,850:950].std()

def takemean( path ):
    fh=fits.open(path)     
    return  fh[0].data[850:950,1050:1070].mean()

def takevariance( path ):
    fh=fits.open(path)
    return  fh[0].data[850:950,1050:1070].var()/2

def takestd( path ):
    fh=fits.open(path)
    return  fh[0].data[850:950,1050:1070].std()

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import matplotlib.patches as patches

# 读取FITS文件
fits_file = "102nm-0006-0d04s-subdark.fit"
# fits_file = "78nm-0006-0d04s-subdark.fit"# 与74 72 ...比有移动
 

with fits.open(fits_file) as hdul:
    data = hdul[0].data

# 定义显示范围
x_min, x_max = 950, 1170
y_min, y_max = 600, 1200

# 定义高亮区域
hx_min, hx_max = 1050, 1070
hy_min, hy_max = 850, 950
 

# 提取子区域
subregion = data[y_min:y_max, x_min:x_max]

# 创建图形
fig, ax = plt.subplots(figsize=(10, 8))

# 显示图像
im = ax.imshow(subregion, 
               cmap='viridis', 
               origin='lower', 
               aspect='auto',
               extent=[x_min, x_max, y_min, y_max])

# 添加高亮区域的虚线框
rect = patches.Rectangle((hx_min, hy_min), 
                         hx_max - hx_min, 
                         hy_max - hy_min,
                         linewidth=2, 
                         linestyle='--', 
                         edgecolor='red',
                         facecolor='none')
ax.add_patch(rect)

# 设置坐标轴和标题
ax.set_xlabel('X Pixel', fontsize=12)
ax.set_ylabel('Y Pixel', fontsize=12)
ax.set_title(f'FITS Image: X({x_min}:{x_max}), Y({y_min}:{y_max})', fontsize=14)

# 添加网格
ax.grid(True, alpha=0.3)

# 添加颜色条
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('ADU', fontsize=12)

plt.tight_layout()
plt.show()

# %%
from glob import glob
import glob
rowsmean = []
for afile in glob.glob("94nm*-subdark-ave.fit"):
    rowsmean.append(takemean(afile))
    print(afile)

rowsvariance = []
for afile in glob.glob("94nm*-5sub6.fit"):
    rowsvariance.append(takevariance(afile))
    print(afile)
print(rowsmean)
print(rowsvariance)
# Out:
# 94nm-0d01s-subdark-ave.fit
# 94nm-0d02s-subdark-ave.fit
# 94nm-0d04s-subdark-ave.fit
# 94nm-0d06s-subdark-ave.fit
# 94nm-0d01s-subdark-5sub6.fit
# 94nm-0d02s-subdark-5sub6.fit
# 94nm-0d04s-subdark-5sub6.fit
# 94nm-0d06s-subdark-5sub6.fit
# [6760.8016, 13175.5884, 25603.834, 38218.71661538462]
# [88577.878752, 169547.734528, 296358.372832, 467024.898528]

# %%
import pylab
X = [] 
Y = []
X = rowsmean
Y = rowsvariance 

pylab.xlabel("ADU")
pylab.ylabel("Variance")
pylab.plot(X,Y,"o")

# z1 = np.polyfit(X, Y, 1)   ###线性拟合
# p1 = np.poly1d(z1)

# gain=1/z1[0] 
 
# print('gain=%f e-/ADU'% gain) 
# ##gain=0.088757 e-/ADU

z1 = np.polyfit(X, Y, 1)   ###线性拟合
p1 = np.poly1d(z1)
z1, cov = np.polyfit(X, Y, 1, cov=True)
slope_error = np.sqrt(cov[0, 0])
print(f"斜率: {z1[0]:.6f} ± {slope_error:.6f}")
gain=1/z1[0]  
print('gain=%f e-/ADU'% gain)
# Out:
# 斜率: 11.827956 ± 0.500156
# gain=0.084545 e-/ADU

# %%
from uncertainties import ufloat
from uncertainties import unumpy
x = ufloat(11.827956  ,0.500156)  
print(f"原始值: {x}")
reciprocal = 1 / x
print(f"倒数: {reciprocal}")

# 提取详细信息
print(f"\n详细结果:")
print(f"倒数值: {reciprocal.nominal_value:.8f}")
print(f"倒数误差: {reciprocal.std_dev:.8f}")
print(f"相对误差: {(reciprocal.std_dev / reciprocal.nominal_value * 100):.4f}%")

print("-----------------------------------------------------------------")
# 输入数据
import math
x_data = rowsmean
y_data = rowsvariance
# X = rowsmean
# Y = rowsvariance
print(x_data)
print(y_data)

# 最小二乘线性拟合 (y = mx + b)
# 使用numpy的polyfit进行一阶多项式拟合
m, b = np.polyfit(x_data, y_data, 1)


print("拟合结果:")
print(f"斜率 m = {m:.6f}")
print(f"截距 b = {b:.6f}")
print(f"拟合公式: y = {m:.6f}x + {b:.6f}")
readnoise=math.sqrt(b)*reciprocal
print(f"读出噪声readoutnoise ={readnoise:.3f}")
# Out:
# 原始值: 11.8+/-0.5
# 倒数: 0.085+/-0.004
#
# 详细结果:
# 倒数值: 0.08454546
# 倒数误差: 0.00357508
# 相对误差: 4.2286%
# -----------------------------------------------------------------
# [6760.8016, 13175.5884, 25603.834, 38218.71661538462]
# [88577.878752, 169547.734528, 296358.372832, 467024.898528]
# 拟合结果:
# 斜率 m = 11.827956
# 截距 b = 7702.954047
# 拟合公式: y = 11.827956x + 7702.954047
# 读出噪声readoutnoise =7.420+/-0.314
