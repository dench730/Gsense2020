# %%
import ccdproc
from os import listdir
from astropy.io import fits
import glob
import pylab
from astropy.table import Table
import numpy as np 
import ccdproc as cp 
from glob import glob
import matplotlib.pyplot as plt
from ccdproc import *   
import astropy.units as u
import os
from glob import glob
import glob
import math

# %%
# subtract_fits_images('HIP19139-g80o50-0001-100ms.fit', 'dark-g80o50-0004-100ms.fit', 'HIP19139-g80o50-0001-100ms-subdark.fit')

# %%
# def takemean( path ):
#     fh=fits.open(path)     
#     return  fh[0].data[1050:1106,930:964].mean()

def takestat( path ):
    fh=fits.open(path)
     
        
    #return fh[0].header["EXPTIME"], fh[0].data[644:1140,860:1110].sum()   ### 取总和   
    return fh[0].header["EXPTIME"], fh[0].data[644:1140,960:1120].sum()   ### 取总和   要尽量大 覆盖到


    #return fh[0].header["EXPTIME"], fh[0].data[975:1114,918:995].mean()   ###取小范围    
    #return fh[0].header["EXPTIME"], fh[0].data[828:1212,886:1068].mean()    ####取适当范围（基本包括全部）


# def takevariance( path ):
#     fh=fits.open(path)
#     return  fh[0].data[1050:1106,930:964].var()/2

def takestd( path ):
    fh=fits.open(path)
    return  fh[0].data[650:1130,910:1150].std()

# %%
rows = []
for afile in glob.glob("74nm-0005-0d10s.fit"):
    rows.append(takestat(afile))
    print(rows)
# Out:
# [(0.1, 568588096)]

# %%
rows = []
for afile in glob.glob("74nm-0006*subdark.fit"):
    rows.append(takestat(afile))
table = Table(rows=rows,names=("exptime","count")) 
pylab.xlabel("exptime")
pylab.ylabel("74nm Count in ADU")
pylab.plot(table["exptime"],table["count"],"o")

print(table["exptime"])
print(table["count"])
#5.236e+09 x - 3.279e+06
# Out:
# exptime
# -------
#    0.01
#    0.04
#     0.1
#     0.2
#       count
# ------------------
# 27957836.800000004
#        107236468.8
# 286702448.00000006
#        551872089.6

# %%
X = table["exptime"]
Y = table["count"]
pylab.xlabel("exptime")
pylab.ylabel("Count(Total)")
pylab.plot(X,Y,"o")

# z1 = np.polyfit(X, Y, 1)   ###线性拟合
# p1 = np.poly1d(z1)

# print('z1=',z1)
# print("拟合后的公式是：")
# print('p1=',p1)

z1 = np.polyfit(X, Y, 1)   ###线性拟合
slope, intercept = z1
y_fit = slope * X + intercept
residuals = Y - y_fit#残差
mse = np.mean(residuals**2)#均方误差
rmse = np.sqrt(mse)#均方根误差
p1 = np.poly1d(z1)
print('RMSE=',rmse)

print('z1=',z1)
print("拟合后的公式是：") 
#print('p1=',p1)#± 

#print("a ==  %s ,b == %s" % (a, b))
print("p1=%s± %s" % (p1,rmse))
# Out:
# RMSE= 5167902.385330116
# z1= [2.77147929e+09 9.37772828e+05]
# 拟合后的公式是：
# p1=
# 2.771e+09 x + 9.378e+05± 5167902.385330116

# %%
from uncertainties import ufloat
x = ufloat(2.771e+09 + 9.378e+05, 5167902.385330116)
print("一秒钟内的count数是",x)
gain =ufloat(0.059,0.005)
electron_num = gain * x
print("一秒钟内的电子数是")
print(f"{electron_num}")  

photo_num= ufloat(397507068.4,2654531.53)

QE=electron_num / photo_num
print(QE)
# Out:
# 一秒钟内的count数是 (2.772+/-0.005)e+09
# 一秒钟内的电子数是
# (1.64+/-0.14)e+08
# 0.411+/-0.035
