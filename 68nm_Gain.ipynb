# %%
import os
import ccdproc
import glob
import subprocess
import itertools
import numpy as np
from astropy import units as u
from astropy.io import fits
from astropy.coordinates import SkyCoord
from astropy.wcs import utils as wcsutils
from astropy.table import Table
from astropy.stats import sigma_clip
from astroquery.simbad import Simbad
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import rc, rcParams
import ccdproc as cp
from ccdproc import *

# %%
# lightlist1=['68nm-0003-0d10s.fit','dark-0d10s-average.fit']
# image1_1 = ccdproc.CCDData.read('./68nm-0003-0d10s.fit', unit='adu',)
# image1_2 = ccdproc.CCDData.read('./dark-0d10s-average.fit', unit='adu',)
# sub_img = ccdproc.subtract_bias(image1_1, image1_2)
# ret = os.access("68nm-0003-0d10s.fit", os.F_OK)
# if(ret==False):
#     sub_img.write('./68nm-0003-0d10s.fit')

# lightlist1=['68nm-0008-0d10s.fit','dark-0d10s-average.fit']
# image1_1 = ccdproc.CCDData.read('./68nm-0008-0d10s.fit', unit='adu',)
# image1_2 = ccdproc.CCDData.read('./dark-0d10s-average.fit', unit='adu',)
# sub_img = ccdproc.subtract_bias(image1_1, image1_2)
# ret = os.access("68nm-0008-0d10s.fit", os.F_OK)
# if(ret==False):
#     sub_img.write('./68nm-0008-0d10s.fit')

# %%
# lightlist1=['68nm-0003-0d20s.fit','dark-0d20s-average.fit']
# image1_1 = ccdproc.CCDData.read('./68nm-0003-0d20s.fit', unit='adu',)
# image1_2 = ccdproc.CCDData.read('./dark-0d20s-average.fit', unit='adu',)
# sub_img = ccdproc.subtract_bias(image1_1, image1_2)
# ret = os.access("68nm-0003-0d20s.fit", os.F_OK)
# if(ret==False):
#     sub_img.write('./68nm-0003-0d20s.fit')

# lightlist1=['68nm-0008-0d20s.fit','dark-0d20s-average.fit']
# image1_1 = ccdproc.CCDData.read('./68nm-0008-0d20s.fit', unit='adu',)
# image1_2 = ccdproc.CCDData.read('./dark-0d20s-average.fit', unit='adu',)
# sub_img = ccdproc.subtract_bias(image1_1, image1_2)
# ret = os.access("68nm-0008-0d20s.fit", os.F_OK)
# if(ret==False):
#     sub_img.write('./68nm-0008-0d20s.fit')

# %%
# lightlist1=['68nm-0003-0d50s.fit','dark-0d50s-average.fit']
# image1_1 = ccdproc.CCDData.read('./68nm-0003-0d50s.fit', unit='adu',)
# image1_2 = ccdproc.CCDData.read('./dark-0d50s-average.fit', unit='adu',)
# sub_img = ccdproc.subtract_bias(image1_1, image1_2)
# ret = os.access("68nm-0003-0d50s.fit", os.F_OK)
# if(ret==False):
#     sub_img.write('./68nm-0003-0d50s.fit')

# lightlist1=['68nm-0008-0d50s.fit','dark-0d50s-average.fit']
# image1_1 = ccdproc.CCDData.read('./68nm-0008-0d50s.fit', unit='adu',)
# image1_2 = ccdproc.CCDData.read('./dark-0d50s-average.fit', unit='adu',)
# sub_img = ccdproc.subtract_bias(image1_1, image1_2)
# ret = os.access("68nm-0008-0d50s.fit", os.F_OK)
# if(ret==False):
#     sub_img.write('./68nm-0008-0d50s.fit')

# %%
# lightlist1=['68nm-0003-1d00s.fit','dark-1d00s-average.fit']
# image1_1 = ccdproc.CCDData.read('./68nm-0003-1d00s.fit', unit='adu',)
# image1_2 = ccdproc.CCDData.read('./dark-1d00s-average.fit', unit='adu',)
# sub_img = ccdproc.subtract_bias(image1_1, image1_2)
# ret = os.access("68nm-0003-1d00s.fit", os.F_OK)
# if(ret==False):
#     sub_img.write('./68nm-0003-1d00s.fit')

# lightlist1=['68nm-0008-1d00s.fit','dark-1d00s-average.fit']
# image1_1 = ccdproc.CCDData.read('./68nm-0008-1d00s.fit', unit='adu',)
# image1_2 = ccdproc.CCDData.read('./dark-1d00s-average.fit', unit='adu',)
# sub_img = ccdproc.subtract_bias(image1_1, image1_2)
# ret = os.access("68nm-0008-1d00s.fit", os.F_OK)
# if(ret==False):
#     sub_img.write('./68nm-0008-1d00s.fit')

# %%
lightlist1=['68nm-0003-0d10s.fit','68nm-0008-0d10s.fit']
image1_1 = ccdproc.CCDData.read('./68nm-0003-0d10s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./68nm-0008-0d10s.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("68nm-0d10s-nodarksub38.fit", os.F_OK)
if(ret==False):
    sub_img.write('./68nm-0d10s-nodarksub38.fit')
    
ret = os.access("68nm-0d10s-nodarkave38.fit", os.F_OK)
if(ret==False):
    avgccd = combine(lightlist1, output_file='68nm-0d10s-nodarkave38.fit',  
                     method='average', unit=u.adu)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.278553 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.278669 from DATE-OBS'. [astropy.wcs.wcs]

# %%
lightlist1=['68nm-0003-0d20s.fit','68nm-0008-0d20s.fit']
image1_1 = ccdproc.CCDData.read('./68nm-0003-0d20s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./68nm-0008-0d20s.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("68nm-0d20s-nodarksub38.fit", os.F_OK)
if(ret==False):
    sub_img.write('./68nm-0d20s-nodarksub38.fit')
    
ret = os.access("68nm-0d20s-nodarkave38.fit", os.F_OK)
if(ret==False):
    avgccd = combine(lightlist1, output_file='68nm-0d20s-nodarkave38.fit',  
                     method='average', unit=u.adu)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.278785 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.278912 from DATE-OBS'. [astropy.wcs.wcs]

# %%
lightlist1=['68nm-0003-0d50s.fit','68nm-0008-0d50s.fit']
image1_1 = ccdproc.CCDData.read('./68nm-0003-0d50s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./68nm-0008-0d50s.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("68nm-0d50s-nodarksub38.fit", os.F_OK)
if(ret==False):
    sub_img.write('./68nm-0d50s-nodarksub38.fit')
    
ret = os.access("68nm-0d50s-nodarkave38.fit", os.F_OK)
if(ret==False):
    avgccd = combine(lightlist1, output_file='68nm-0d50s-nodarkave38.fit',  
                     method='average', unit=u.adu)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.279039 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.279178 from DATE-OBS'. [astropy.wcs.wcs]

# %%
lightlist1=['68nm-0003-1d00s.fit','68nm-0008-1d00s.fit']
image1_1 = ccdproc.CCDData.read('./68nm-0003-1d00s.fit', unit='adu',)
image1_2 = ccdproc.CCDData.read('./68nm-0008-1d00s.fit', unit='adu',)
sub_img = ccdproc.subtract_bias(image1_1, image1_2)
ret = os.access("68nm-1d00s-nodarksub38.fit", os.F_OK)
if(ret==False):
    sub_img.write('./68nm-1d00s-nodarksub38.fit')
    
ret = os.access("68nm-1d00s-nodarkave38.fit", os.F_OK)
if(ret==False):
    avgccd = combine(lightlist1, output_file='68nm-1d00s-nodarkave38.fit',  
                     method='average', unit=u.adu)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.279687 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60988.279861 from DATE-OBS'. [astropy.wcs.wcs]

# %%
# def takemean( path ):
#     fh=fits.open(path)     
#     return  fh[0].data[1020:1060,850:950].mean()

# def takevariance( path ):
#     fh=fits.open(path)
#     return  fh[0].data[1020:1060,850:950].var()/2

# def takestd( path ):
#     fh=fits.open(path)
#     return  fh[0].data[1020:1060,850:950].std()

def takemean( path ):
    fh=fits.open(path)     
    return  fh[0].data[850:950,1030:1050].mean()

def takevariance( path ):
    fh=fits.open(path)
    return  fh[0].data[850:950,1030:1050].var()/2

def takestd( path ):
    fh=fits.open(path)
    return  fh[0].data[850:950,1030:1050].std()

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import matplotlib.patches as patches

# 读取FITS文件
fits_file = "68nm-0008-0d20s.fit"
# fits_file = "78nm-0006-0d04s-subdark.fit"# 与74 72 ...比有移动

#fits_file = "104nm-0006-0d04s-subdark.fit"# 与74 72 ...比有移动

#fits_file = "125nm-0006-0d04s-subdark.fit"# 与74 72 ...比有移动 移动更大
#fits_file = "140nm-0006-0d02s-subdark.fit"# 与74 72 ...比有移动 移动更大
#fits_file = "60nm-0006-0d04s-subdark.fit"

with fits.open(fits_file) as hdul:
    data = hdul[0].data

# 定义显示范围
x_min, x_max = 950, 1170
y_min, y_max = 600, 1200

# 定义高亮区域
hx_min, hx_max = 1030, 1050
hy_min, hy_max = 850, 950
# hx_min, hx_max = 980, 1000 #125nm
# hy_min, hy_max = 900, 1000

# 提取子区域
subregion = data[y_min:y_max, x_min:x_max]

# 创建图形
fig, ax = plt.subplots(figsize=(10, 8))

# 显示图像
im = ax.imshow(subregion, 
               cmap='viridis', 
               origin='lower', 
               aspect='auto',
               extent=[x_min, x_max, y_min, y_max])

# 添加高亮区域的虚线框
rect = patches.Rectangle((hx_min, hy_min), 
                         hx_max - hx_min, 
                         hy_max - hy_min,
                         linewidth=2, 
                         linestyle='--', 
                         edgecolor='red',
                         facecolor='none')
ax.add_patch(rect)

# 设置坐标轴和标题
ax.set_xlabel('X Pixel', fontsize=12)
ax.set_ylabel('Y Pixel', fontsize=12)
ax.set_title(f'FITS Image: X({x_min}:{x_max}), Y({y_min}:{y_max})', fontsize=14)

# 添加网格
ax.grid(True, alpha=0.3)

# 添加颜色条
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('ADU', fontsize=12)

plt.tight_layout()
plt.show()

# %%
from glob import glob
import glob
rowsmean = []
for afile in glob.glob("68nm*-nodarkave38.fit"):
    rowsmean.append(takemean(afile))
    print(afile)

rowsvariance = []
for afile in glob.glob("68nm*-nodarksub38.fit"):
    rowsvariance.append(takevariance(afile))
    print(afile)
print(rowsmean)
print(rowsvariance)
# Out:
# 68nm-0d10s-nodarkave38.fit
# 68nm-0d20s-nodarkave38.fit
# 68nm-0d50s-nodarkave38.fit
# 68nm-1d00s-nodarkave38.fit
# 68nm-0d10s-nodarksub38.fit
# 68nm-0d20s-nodarksub38.fit
# 68nm-0d50s-nodarksub38.fit
# 68nm-1d00s-nodarksub38.fit
# [4587.536, 6240.248, 11008.984, 18697.632]
# [115843.297152, 218601.557888, 589755.745152, 1170642.103168]

# %%
import pylab
X = [] 
Y = []
X = rowsmean
Y = rowsvariance 

pylab.xlabel("ADU")
pylab.ylabel("Variance")
pylab.plot(X,Y,"o")

# z1 = np.polyfit(X, Y, 1)   ###线性拟合
# p1 = np.poly1d(z1)

# gain=1/z1[0] 
 
# print('gain=%f e-/ADU'% gain) 
# ##以前的结果 gain=0.013920 e-/ADU


z1 = np.polyfit(X, Y, 1)   ###线性拟合
p1 = np.poly1d(z1)
z1, cov = np.polyfit(X, Y, 1, cov=True)
slope_error = np.sqrt(cov[0, 0])
print(f"斜率: {z1[0]:.6f} ± {slope_error:.6f}")
gain=1/z1[0]  
print('gain=%f e-/ADU'% gain)
# Out:
# 斜率: 75.384627 ± 1.002063
# gain=0.013265 e-/ADU

# %%
from uncertainties import ufloat
from uncertainties import unumpy
x = ufloat(75.384627  , 1.002063)  
print(f"原始值: {x}")
reciprocal = 1 / x
print(f"倒数: {reciprocal}")

# 提取详细信息
print(f"\n详细结果:")
print(f"倒数值: {reciprocal.nominal_value:.8f}")
print(f"倒数误差: {reciprocal.std_dev:.8f}")
print(f"相对误差: {(reciprocal.std_dev / reciprocal.nominal_value * 100):.4f}%")


# print("-----------------------------------------------------------------")
# # 输入数据
# import math
# x_data = rowsmean
# y_data = rowsvariance
# # X = rowsmean
# # Y = rowsvariance
# print(x_data)
# print(y_data)

# # 最小二乘线性拟合 (y = mx + b)
# # 使用numpy的polyfit进行一阶多项式拟合
# m, b = np.polyfit(x_data, y_data, 1)


# print("拟合结果:")
# print(f"斜率 m = {m:.6f}")
# print(f"截距 b = {b:.6f}")
# print(f"拟合公式: y = {m:.6f}x + {b:.6f}")
# readnoise=math.sqrt(b)*reciprocal
# print(f"读出噪声readoutnoise ={readnoise:.3f}")
# Out:
# 原始值: 75.4+/-1.0
# 倒数: 0.01327+/-0.00018
#
# 详细结果:
# 倒数值: 0.01326530
# 倒数误差: 0.00017633
# 相对误差: 1.3293%
# -----------------------------------------------------------------
# [4587.536, 6240.248, 11008.984, 18697.632]
# [115843.297152, 218601.557888, 589755.745152, 1170642.103168]
# 拟合结果:
# 斜率 m = 75.384627
# 截距 b = -240206.982779
# 拟合公式: y = 75.384627x + -240206.982779
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 34
#      32 print(f"截距 b = {b:.6f}")
#      33 print(f"拟合公式: y = {m:.6f}x + {b:.6f}")
# ---> 34 readnoise=math.sqrt(b)*reciprocal
#      35 print(f"读出噪声readoutnoise ={readnoise:.3f}")
#
# ValueError: math domain error
